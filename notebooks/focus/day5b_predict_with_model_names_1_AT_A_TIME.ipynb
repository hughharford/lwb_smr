# %% [markdown]
# ## 220612 Our set of models, predicting and visualising each:

# %%
from lwb_smr.CustomDataLoader import CustomDataLoader
from lwb_smr.data import LoadDataSets
import os
from pathlib import Path
import tensorflow as tf
import matplotlib.pyplot as plt
import random
from PIL import Image, ImageDraw

# %%
MODEL_NAMES = {
    'first_VGG16_full_bce': '220610_checkpoint_.h5',
    'latest_VVG16_bce': '220610_full_model_vgg16_10e_20e_more.h5',
    'latest_VGG16_dice': '220611_v7_UNET_VGG16_Dice_input_shape_224x224x3.h5',
    
}
RAW_DATA_PATH = '../../../raw_data/'
GCP_MODELS_PATH = 'lwb-solar-my-roof/models/'
PATH_HERE = 'lwb_smr/notebooks/day5'

# %% [markdown]
# # CHANGE THIS KEY TO LOAD THE MODEL YOU WANT

# %%
this_model = MODEL_NAMES['latest_VGG16_dice']
this_model
# Out:
# '220611_v7_UNET_VGG16_Dice_input_shape_224x224x3.h5'

# %%
model_load_string = f'{RAW_DATA_PATH}models/{this_model}'
path = Path(model_load_string)
assert path.is_file()

# %%
model_load_string
# Out:
# '../../../raw_data/models/220611_v7_UNET_VGG16_Dice_input_shape_224x224x3.h5'

# %%
print('copy THESE 2 LINES to push the model: '+ this_model + ' to the gcp bucket')
print('')
print(f'cd {PATH_HERE}')
print(f'gsutil cp {model_load_string} gs://{GCP_MODELS_PATH}{this_model}')
# Out:
# copy THESE 2 LINES to push the model: 220611_v7_UNET_VGG16_Dice_input_shape_224x224x3.h5 to the gcp bucket
#
# cd lwb_smr/notebooks/day5
# gsutil cp ../../../raw_data/models/220611_v7_UNET_VGG16_Dice_input_shape_224x224x3.h5 gs://lwb-solar-my-roof/models/220611_v7_UNET_VGG16_Dice_input_shape_224x224x3.h5

# %% [markdown]
# # LOAD THE MODEL SPECIFIED ABOVE:

# %%
model_load_string
# Out:
# '../../../raw_data/models/220611_v7_UNET_VGG16_Dice_input_shape_224x224x3.h5'

# %%
def dice_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.math.sigmoid(y_pred)
    numerator = 2 * tf.reduce_sum(y_true * y_pred)
    denominator = tf.reduce_sum(y_true + y_pred)

    return 1 - numerator / denominator

# %%
from tensorflow.keras.models import Model, Sequential

custom_objects_dict = {
                'dice_loss': dice_loss
}
loaded_model = tf.keras.models.load_model(model_load_string, custom_objects=custom_objects_dict)
# Out:
# 2022-06-12 13:19:16.203954: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 13:19:16.214999: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 13:19:16.215706: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 13:19:16.216942: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-12 13:19:16.218952: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 13:19:16.219680: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 13:19:16.220364: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 13:19:16.730897: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 13:19:16.731644: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 13:19:16.732226: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 13:19:16.732770: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13823 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5

# %%
# Check its architecture
loaded_model.summary()
# Out:
# Model: "first_VGG16_UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 224, 224, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 224, 224, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 112, 112, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 112, 112, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 112, 112, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 56, 56, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 56, 56, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 56, 56, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 56, 56, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 28, 28, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 28, 28, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 28, 28, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 28, 28, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 14, 14, 512)  0           ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 14, 14, 512)  2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 14, 14, 512)  2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 14, 14, 512)  2359808     ['block5_conv2[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 28, 28, 512)  1049088    ['block5_conv3[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 28, 28, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'block4_conv3[0][0]']
#
#  conv2d (Conv2D)                (None, 28, 28, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization (BatchNorm  (None, 28, 28, 512)  2048       ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 28, 28, 512)  0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 512)  2359808     ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 28, 512)  2048       ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 28, 28, 512)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 56, 56, 256)  524544     ['activation_1[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'block3_conv3[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 256)  1179904     ['concatenate_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 256)  1024       ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 56, 56, 256)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 256)  590080      ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 256)  1024       ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 56, 56, 256)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 112, 112, 12  131200     ['activation_3[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 112, 112, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'block2_conv2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 112, 112, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_4 (BatchNo  (None, 112, 112, 12  512        ['conv2d_4[0][0]']
#  rmalization)                   8)
#
#  activation_4 (Activation)      (None, 112, 112, 12  0           ['batch_normalization_4[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 112, 112, 12  147584      ['activation_4[0][0]']
#                                 8)
#
#  batch_normalization_5 (BatchNo  (None, 112, 112, 12  512        ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  activation_5 (Activation)      (None, 112, 112, 12  0           ['batch_normalization_5[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 224, 224, 64  32832      ['activation_5[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 224, 224, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'block1_conv2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 224, 224, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 224, 224, 64  256        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 224, 224, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 224, 224, 64  36928       ['activation_6[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 224, 224, 64  256        ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 224, 224, 64  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 224, 224, 1)  65          ['activation_7[0][0]']
#
# ==================================================================================================
# Total params: 25,862,337
# Trainable params: 11,143,809
# Non-trainable params: 14,718,528
# __________________________________________________________________________________________________

# %% [markdown]
# # PREDICT TOO

# %%
def plot_comparison(X_true, y_true, y_pred, a=0, b=1, c=2):
    """
    Function: Plots a 3x3 grid comparing test_image, mask_image, predicted_mask
    Inputs: X_true - [NumPy array] - RGB Image
            y_true - [NumPy array] - Mask of image to predict
            y_pred - [NumPy array] - predicted mask 
            a, b, c - [integer] - index of images to select from arrays 
    """
    
    f, axs = plt.subplots(3, 3, figsize=(12, 12))
    titles = ['Test Image', 'Test Label', 'Prediction Label',
             'Test Image', 'Test Label', 'Prediction Label',
             'Test Image', 'Test Label', 'Prediction Label'
             ]


    ax1, ax2, ax3 = axs[0,0], axs[0,1], axs[0,2]
    ax4, ax5, ax6 = axs[1,0], axs[1,1], axs[1,2]
    ax7, ax8, ax9 = axs[2,0], axs[2,1], axs[2,2]
    # idx = random.sample(range(0, X_test[:,:,:,:].shape[0]), 3)

    ax1.imshow(X_true) # [a,:,:,:])
    ax1.set_title('Test Image')
    ax2.imshow(y_true, cmap='gray') # [a,:,:,0])
    ax2.set_title('True Mask')
    ax3.imshow(y_pred, cmap='gray') # [a,:,:,0])
    ax3.set_title('Predicted Mask')

#     ax4.imshow(X_true[b,:,:,:])
#     ax5.imshow(y_true[b,:,:,0])
#     ax6.imshow(y_pred[b,:,:,0])

#     ax7.imshow(X_true[c,:,:,:])
#     ax8.imshow(y_true[c,:,:,0])
#     ax9.imshow(y_pred[c,:,:,0])

# %% [markdown]
# # JOSH input on getting PRED data out (adjusted out of class)

# %%
# ds_train_test = tf.data.Dataset.from_tensor_slices(
#      (train_test_df["image_path"].values, train_test_df["mask_path"].values)
# )        
# AUTOTUNE = tf.data.experimental.AUTOTUNE
# ds_train_test = ds_train_test.map(process_path) \
# .map(self.normalize) \
# .batch(batch_size=BATCH_SIZE) \
# .prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### LOAD ONE DATA POINT FOR PREDICTION

# %%
start_point = 226
no_points = 3
end_point = start_point+no_points
data_dict = LoadDataSets(RAW_DATA_PATH + "image_datasets_csv/train_dataset.csv",RAW_DATA_PATH + "image_datasets_csv/validation_dataset.csv").load_datasets()
predict_data = CustomDataLoader(data_dict['train_x'][start_point:end_point],RAW_DATA_PATH + "train_RGB_tiles_jpeg/",
                                data_dict['train_y'][start_point:end_point],RAW_DATA_PATH + "train_mask_tiles_jpeg/",
                                (250,250),16)
# Out:
# Datasets match, proceed

# %%
predict_data.__dict__
# Out:
# {'x': ['chicago32_x14_y12.jpeg',
#   'chicago31_x07_y11.jpeg',
#   'austin21_x04_y14.jpeg'],
#  'y': ['chicago32_mask_x14_y12.jpeg',
#   'chicago31_mask_x07_y11.jpeg',
#   'austin21_mask_x04_y14.jpeg'],
#  'x_path': '../../../raw_data/train_RGB_tiles_jpeg/',
#  'y_path': '../../../raw_data/train_mask_tiles_jpeg/',
#  'input_image_size': (250, 250),
#  'batch_size': 16}

# %%
X_true_path = [predict_data.x_path+predict_data.x[0]]
X_true = Image.open(X_true_path[0])
X_true
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>

# %%
y_true_path = [predict_data.y_path+predict_data.y[0]]
y_true = Image.open(y_true_path[0])
y_true
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=250x250>

# %%
def predict(model):
    y_pred = model.predict(predict_data)
    return y_pred

# %%
y_pred = predict(loaded_model)[0]
display(y_pred.shape)
# y_pred
# Out:
# (224, 224, 1)

# %%
# y_pred_img = Image.fromarray(y_pred, 'L')
y_pred_img = tf.keras.utils.array_to_img(y_pred)
y_pred_img
# Out:
# <PIL.Image.Image image mode=L size=224x224>

# %%
plot_comparison(X_true, y_true, y_pred_img)
