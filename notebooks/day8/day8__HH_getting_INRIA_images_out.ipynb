# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import os

# %%
from lwb_smr.data import GetData, LoadDataSets
from lwb_smr.custom_data_loader import CustomDataLoader
# Out:
# 2022-06-15 15:14:56.526309: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-15 15:14:56.526331: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# !ls "../../raw_data/"
# Out:
# AerialImageDataset	    __EX		    presentation
# checkpoints		    image_datasets_csv	    tiles
# data_samples		    image_datasets_csv.zip  train_mask_tiles_jpeg
# data_samples.zip	    london		    train_RGB_tiles_jpeg
# data_vertex_data_jpegs.zip  models		    x_pred

# %%
###########################
# GetDat input parameters #
###########################

train_path = "../../raw_data/train_RGB_tiles_jpeg/"
mask_path = "../../raw_data/train_mask_tiles_jpeg/"
input_image_size = (250,250)
train_percent = 0.7
validation_percent = 0.25
test_percent = 0.05

# %%
dataset = GetData(train_path,mask_path,train_percent,validation_percent,test_percent)
data_dict = dataset.get_datasets()
data_dict.keys()
# Out:
# Datasets match, proceed
# dict_keys(['train_x', 'train_y', 'val_x', 'val_y', 'test_x', 'test_y'])

# %%
# dataset_save_path = "../../raw_data/saved_dataset_csvs/jk_090622/"

# %%
# check lengths and sums are ok

# %%
train_x_for_im = data_dict['train_x'][570:630]
train_y_for_im = data_dict['train_y'][570:630]

# %%
import matplotlib.pyplot as plt 
from PIL import Image

# for i in range(len(train_x_for_im)):
x = 50
display(Image.open(train_path+train_x_for_im[x]))
display(Image.open(mask_path+train_y_for_im[x]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x7F7A6199E610>
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=250x250 at 0x7F7A6199EE50>
